# %%
import os
import requests
import cloudinary
import cloudinary.api
from dotenv import load_dotenv
import time
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

# %%
# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %%
# Configure Cloudinary using environment variables
cloudinary.config(
    cloud_name=os.getenv('CLOUDINARY_CLOUD_NAME'),
    api_key=os.getenv('CLOUDINARY_API_KEY'),
    api_secret=os.getenv('CLOUDINARY_API_SECRET')
)

# %%
def create_requests_session(retries=3, backoff_factor=0.3, status_forcelist=(500, 502, 504)):
    """
    Create a requests session with retry capabilities
    """
    session = requests.Session()
    retry = Retry(
        total=retries,
        read=retries,
        connect=retries,
        backoff_factor=backoff_factor,
        status_forcelist=status_forcelist,
    )
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    return session

def download_image(url, download_path, session=None):
    """
    Download image with improved error handling and retry mechanism
    """
    if session is None:
        session = requests.Session()
    
    try:
        # Add a timeout to the request
        response = session.get(url, timeout=(10, 30))  # (connect timeout, read timeout)
        
        if response.status_code == 200:
            # Ensure directory exists
            os.makedirs(os.path.dirname(download_path), exist_ok=True)
            
            with open(download_path, 'wb') as f:
                f.write(response.content)
            print(f"Downloaded: {download_path}")
            return True
        else:
            print(f"Failed to download image from {url}. Status code: {response.status_code}")
            return False
    
    except requests.exceptions.RequestException as e:
        print(f"Error downloading {url}: {e}")
        return False

def fetch_and_download_images(folder_name, download_dir, max_retries=3):
    """
    Fetch and download images with improved error handling
    """
    # Create a requests session with retry capabilities
    session = create_requests_session()
    
    try:
        # Increase max_results if needed, or use pagination
        resources = cloudinary.api.resources(type="upload", prefix=folder_name, max_results=1000)
        
        if not resources.get('resources'):
            print(f"No resources found in the folder {folder_name}.")
            return
        
        # Ensure the download directory exists
        os.makedirs(download_dir, exist_ok=True)
        
        # Track download progress
        total_images = len(resources['resources'])
        downloaded_images = 0
        failed_images = []
        
        for resource in resources['resources']:
            image_url = resource['secure_url']
            public_id = resource['public_id']
            
            # Remove 'financial_data/' from the public_id 
            local_path = public_id.replace(f'{folder_name}/', '')
            
            # Create the full local path
            download_path = os.path.join(download_dir, f"{local_path}.jpg")
            
            # Attempt download with retries
            success = False
            for attempt in range(max_retries):
                if download_image(image_url, download_path, session):
                    success = True
                    downloaded_images += 1
                    break
                
                # Wait a bit before retrying
                time.sleep(2 ** attempt)  # Exponential backoff
            
            if not success:
                failed_images.append(image_url)
                print(f"Failed to download {image_url} after {max_retries} attempts")
            
            # Optional: Add a small delay between downloads to reduce load
            time.sleep(0.1)
        
        # Print summary
        print(f"\nDownload Summary:")
        print(f"Total Images: {total_images}")
        print(f"Successfully Downloaded: {downloaded_images}")
        print(f"Failed Downloads: {len(failed_images)}")
        
        # Optionally, log failed image URLs
        if failed_images:
            with open(os.path.join(download_dir, 'failed_downloads.txt'), 'w') as f:
                f.write("\n".join(failed_images))
    
    except Exception as e:
        print(f"Error fetching resources: {e}")

# Specify the Cloudinary folder name and the local directory to save images
folder_name = "financial_data"
download_dir = "./downloaded_financial_data"

# Fetch and download images from the folder
fetch_and_download_images(folder_name, download_dir)
# Out:
# Downloaded: ./downloaded_financial_data\bank_statements/image1.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image10.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image100.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image101.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image102.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image103.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image104.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image105.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image106.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image11.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image110.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image111.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image113.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image114.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image115.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image116.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image117.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image118.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image12.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image121.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image122.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image123.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image127.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image128.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image129.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image13.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image130.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image131.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image134.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image135.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image136.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image139.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image14.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image140.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image142.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image143.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image144.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image145.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image146.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image147.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image148.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image149.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image15.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image17.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image18.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image19.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image2.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image20.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image22.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image23.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image24.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image25.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image26.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image27.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image28.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image29.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image3.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image31.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image32.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image33.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image34.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image36.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image37.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image38.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image39.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image4.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image40.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image42.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image45.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image46.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image48.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image5.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image50.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image51.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image52.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image54.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image55.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image56.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image57.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image59.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image6.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image60.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image62.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image64.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image65.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image66.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image67.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image69.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image7.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image72.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image73.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image74.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image76.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image77.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image78.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image79.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image80.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image82.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image83.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image84.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image86.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image87.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image88.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image89.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image90.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image91.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image92.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image93.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image94.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image95.jpg
# Downloaded: ./downloaded_financial_data\bank_statements/image96.jpg
# Downloaded: ./downloaded_financial_data\cheques/image1.jpg
# Downloaded: ./downloaded_financial_data\cheques/image10.jpg
# Downloaded: ./downloaded_financial_data\cheques/image102.jpg
# Downloaded: ./downloaded_financial_data\cheques/image103.jpg
# Downloaded: ./downloaded_financial_data\cheques/image104.jpg
# Downloaded: ./downloaded_financial_data\cheques/image105.jpg
# Downloaded: ./downloaded_financial_data\cheques/image107.jpg
# Downloaded: ./downloaded_financial_data\cheques/image108.jpg
# Downloaded: ./downloaded_financial_data\cheques/image109.jpg
# Downloaded: ./downloaded_financial_data\cheques/image11.jpg
# Downloaded: ./downloaded_financial_data\cheques/image112.jpg
# Downloaded: ./downloaded_financial_data\cheques/image114.jpg
# Downloaded: ./downloaded_financial_data\cheques/image117.jpg
# Downloaded: ./downloaded_financial_data\cheques/image12.jpg
# Downloaded: ./downloaded_financial_data\cheques/image121.jpg
# Downloaded: ./downloaded_financial_data\cheques/image125.jpg
# Downloaded: ./downloaded_financial_data\cheques/image13.jpg
# Downloaded: ./downloaded_financial_data\cheques/image130.jpg
# Downloaded: ./downloaded_financial_data\cheques/image131.jpg
# Downloaded: ./downloaded_financial_data\cheques/image135.jpg
# Downloaded: ./downloaded_financial_data\cheques/image14.jpg
# Downloaded: ./downloaded_financial_data\cheques/image143.jpg
# Downloaded: ./downloaded_financial_data\cheques/image145.jpg
# Downloaded: ./downloaded_financial_data\cheques/image15.jpg
# Downloaded: ./downloaded_financial_data\cheques/image16.jpg
# Downloaded: ./downloaded_financial_data\cheques/image17.jpg
# Downloaded: ./downloaded_financial_data\cheques/image19.jpg
# Downloaded: ./downloaded_financial_data\cheques/image2.jpg
# Downloaded: ./downloaded_financial_data\cheques/image20.jpg
# Downloaded: ./downloaded_financial_data\cheques/image21.jpg
# Downloaded: ./downloaded_financial_data\cheques/image22.jpg
# Downloaded: ./downloaded_financial_data\cheques/image23.jpg
# Downloaded: ./downloaded_financial_data\cheques/image24.jpg
# Downloaded: ./downloaded_financial_data\cheques/image25.jpg
# Downloaded: ./downloaded_financial_data\cheques/image26.jpg
# Downloaded: ./downloaded_financial_data\cheques/image27.jpg
# Downloaded: ./downloaded_financial_data\cheques/image28.jpg
# Downloaded: ./downloaded_financial_data\cheques/image29.jpg
# Downloaded: ./downloaded_financial_data\cheques/image3.jpg
# Downloaded: ./downloaded_financial_data\cheques/image30.jpg
# Downloaded: ./downloaded_financial_data\cheques/image31.jpg
# Downloaded: ./downloaded_financial_data\cheques/image32.jpg
# Downloaded: ./downloaded_financial_data\cheques/image33.jpg
# Downloaded: ./downloaded_financial_data\cheques/image34.jpg
# Downloaded: ./downloaded_financial_data\cheques/image35.jpg
# Downloaded: ./downloaded_financial_data\cheques/image36.jpg
# Downloaded: ./downloaded_financial_data\cheques/image37.jpg
# Downloaded: ./downloaded_financial_data\cheques/image38.jpg
# Downloaded: ./downloaded_financial_data\cheques/image39.jpg
# Downloaded: ./downloaded_financial_data\cheques/image4.jpg
# Downloaded: ./downloaded_financial_data\cheques/image40.jpg
# Downloaded: ./downloaded_financial_data\cheques/image41.jpg
# Downloaded: ./downloaded_financial_data\cheques/image43.jpg
# Downloaded: ./downloaded_financial_data\cheques/image44.jpg
# Downloaded: ./downloaded_financial_data\cheques/image45.jpg
# Downloaded: ./downloaded_financial_data\cheques/image46.jpg
# Downloaded: ./downloaded_financial_data\cheques/image47.jpg
# Downloaded: ./downloaded_financial_data\cheques/image48.jpg
# Downloaded: ./downloaded_financial_data\cheques/image49.jpg
# Downloaded: ./downloaded_financial_data\cheques/image5.jpg
# Downloaded: ./downloaded_financial_data\cheques/image50.jpg
# Downloaded: ./downloaded_financial_data\cheques/image51.jpg
# Downloaded: ./downloaded_financial_data\cheques/image52.jpg
# Downloaded: ./downloaded_financial_data\cheques/image53.jpg
# Downloaded: ./downloaded_financial_data\cheques/image54.jpg
# Downloaded: ./downloaded_financial_data\cheques/image55.jpg
# Downloaded: ./downloaded_financial_data\cheques/image56.jpg
# Downloaded: ./downloaded_financial_data\cheques/image57.jpg
# Downloaded: ./downloaded_financial_data\cheques/image58.jpg
# Downloaded: ./downloaded_financial_data\cheques/image59.jpg
# Downloaded: ./downloaded_financial_data\cheques/image6.jpg
# Downloaded: ./downloaded_financial_data\cheques/image60.jpg
# Downloaded: ./downloaded_financial_data\cheques/image62.jpg
# Downloaded: ./downloaded_financial_data\cheques/image63.jpg
# Downloaded: ./downloaded_financial_data\cheques/image65.jpg
# Downloaded: ./downloaded_financial_data\cheques/image69.jpg
# Downloaded: ./downloaded_financial_data\cheques/image7.jpg
# Downloaded: ./downloaded_financial_data\cheques/image71.jpg
# Downloaded: ./downloaded_financial_data\cheques/image72.jpg
# Downloaded: ./downloaded_financial_data\cheques/image75.jpg
# Downloaded: ./downloaded_financial_data\cheques/image76.jpg
# Downloaded: ./downloaded_financial_data\cheques/image77.jpg
# Downloaded: ./downloaded_financial_data\cheques/image79.jpg
# Downloaded: ./downloaded_financial_data\cheques/image8.jpg
# Downloaded: ./downloaded_financial_data\cheques/image80.jpg
# Downloaded: ./downloaded_financial_data\cheques/image82.jpg
# Downloaded: ./downloaded_financial_data\cheques/image83.jpg
# Downloaded: ./downloaded_financial_data\cheques/image84.jpg
# Downloaded: ./downloaded_financial_data\cheques/image85.jpg
# Downloaded: ./downloaded_financial_data\cheques/image86.jpg
# Downloaded: ./downloaded_financial_data\cheques/image87.jpg
# Downloaded: ./downloaded_financial_data\cheques/image88.jpg
# Downloaded: ./downloaded_financial_data\cheques/image89.jpg
# Downloaded: ./downloaded_financial_data\cheques/image9.jpg
# Downloaded: ./downloaded_financial_data\cheques/image90.jpg
# Downloaded: ./downloaded_financial_data\cheques/image91.jpg
# Downloaded: ./downloaded_financial_data\cheques/image94.jpg
# Downloaded: ./downloaded_financial_data\cheques/image95.jpg
# Downloaded: ./downloaded_financial_data\cheques/image98.jpg
# Downloaded: ./downloaded_financial_data\cheques/image99.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image1.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image10.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image100.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image101.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image104.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image109.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image111.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image112.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image113.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image118.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image120.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image124.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image125.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image126.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image127.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image129.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image130.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image136.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image138.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image139.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image14.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image140.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image142.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image143.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image16.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image17.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image18.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image20.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image21.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image24.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image27.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image28.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image29.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image3.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image30.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image31.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image33.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image35.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image37.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image4.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image42.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image46.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image47.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image48.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image50.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image52.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image55.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image56.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image57.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image58.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image60.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image63.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image64.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image65.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image66.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image67.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image7.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image70.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image71.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image74.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image75.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image78.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image80.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image81.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image82.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image83.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image87.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image88.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image90.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image91.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image93.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image95.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image96.jpg
# Downloaded: ./downloaded_financial_data\profit_loss_statements/image97.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image10.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image100.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image101.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image102.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image105.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image106.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image108.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image11.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image110.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image113.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image115.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image116.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image117.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image118.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image119.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image12.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image120.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image122.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image123.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image124.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image125.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image126.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image127.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image128.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image13.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image131.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image132.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image134.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image135.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image138.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image139.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image14.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image142.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image143.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image144.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image145.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image147.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image15.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image17.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image2.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image20.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image21.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image24.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image26.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image29.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image3.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image31.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image32.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image33.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image34.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image36.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image37.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image38.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image4.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image40.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image43.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image45.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image47.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image49.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image5.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image51.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image52.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image53.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image55.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image56.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image59.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image6.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image60.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image62.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image63.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image66.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image68.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image7.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image71.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image72.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image75.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image78.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image79.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image8.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image80.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image83.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image84.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image88.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image89.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image9.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image92.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image93.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image95.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image96.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image97.jpg
# Downloaded: ./downloaded_financial_data\salary_slips/image98.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image10.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image100.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image101.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image103.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image106.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image107.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image108.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image109.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image11.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image110.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image111.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image112.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image113.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image114.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image115.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image116.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image117.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image118.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image119.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image120.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image121.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image122.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image124.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image128.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image129.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image13.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image131.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image132.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image133.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image136.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image137.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image138.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image17.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image19.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image2.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image20.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image21.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image22.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image23.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image24.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image25.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image26.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image27.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image28.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image29.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image3.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image31.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image32.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image33.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image34.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image35.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image39.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image40.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image41.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image42.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image43.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image44.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image45.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image46.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image48.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image49.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image5.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image50.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image51.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image53.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image54.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image55.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image56.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image57.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image58.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image59.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image6.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image60.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image61.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image62.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image63.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image64.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image66.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image67.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image68.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image69.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image7.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image70.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image72.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image73.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image74.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image75.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image76.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image77.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image78.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image79.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image8.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image80.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image81.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image82.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image83.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image84.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image88.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image9.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image91.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image92.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image93.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image94.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image95.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image96.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image98.jpg
# Downloaded: ./downloaded_financial_data\transaction_history/image99.jpg
#
# Download Summary:
# Total Images: 483
# Successfully Downloaded: 483
# Failed Downloads: 0
